# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelarguelles/Speech-to-Text-Transcription-Tool-v2/blob/main/20240624_Speech(LongAudio_Estereo)_to_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para este ejemplo se utilizó un audio de 3 horas de duración:
#
# https://www.facebook.com/share/v/N1WrLDh6dr3c9Ppi/?mibextid=oFDknk
#
#
# El archivo .mp3 lo pueden descargar de la siguiente ruta:

# %%
##Complemento para convertir de .mp3 a .wav
# !ffmpeg -version
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
# libavutil      56. 70.100 / 56. 70.100
# libavcodec     58.134.100 / 58.134.100
# libavformat    58. 76.100 / 58. 76.100
# libavdevice    58. 13.100 / 58. 13.100
# libavfilter     7.110.100 /  7.110.100
# libswscale      5.  9.100 /  5.  9.100
# libswresample   3.  9.100 /  3.  9.100
# libpostproc    55.  9.100 / 55.  9.100

# %%
##Paquete de OpenAI
# !pip install openai

# !pip install pattern

# !pip install -q git+https://github.com/openai/whisper.git > /dev/null
# !pip install -q git+https://github.com/pyannote/pyannote-audio > /dev/null
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.35.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.4)
# Requirement already satisfied: pattern in /usr/local/lib/python3.10/dist-packages (3.6)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pattern) (0.18.3)
# Requirement already satisfied: backports.csv in /usr/local/lib/python3.10/dist-packages (from pattern) (1.0.7)
# Requirement already satisfied: mysqlclient in /usr/local/lib/python3.10/dist-packages (from pattern) (2.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from pattern) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pattern) (4.9.4)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.10/dist-packages (from pattern) (6.0.11)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from pattern) (20231228)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pattern) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pattern) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from pattern) (3.8.1)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (from pattern) (1.1.2)
# Requirement already satisfied: cherrypy in /usr/local/lib/python3.10/dist-packages (from pattern) (18.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pattern) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->pattern) (2.5)
# Requirement already satisfied: cheroot>=8.2.1 in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern) (10.0.1)
# Requirement already satisfied: portend>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern) (3.2.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern) (10.1.0)
# Requirement already satisfied: zc.lockfile in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern) (3.0.post1)
# Requirement already satisfied: jaraco.collections in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern) (5.0.1)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser->pattern) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->pattern) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->pattern) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->pattern) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->pattern) (4.66.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->pattern) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->pattern) (42.0.8)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->pattern) (4.12.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pattern) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pattern) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pattern) (2024.6.2)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.10/dist-packages (from cheroot>=8.2.1->cherrypy->pattern) (4.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.16.0)
# Requirement already satisfied: tempora>=1.8 in /usr/local/lib/python3.10/dist-packages (from portend>=2.1.1->cherrypy->pattern) (5.6.0)
# Requirement already satisfied: jaraco.text in /usr/local/lib/python3.10/dist-packages (from jaraco.collections->cherrypy->pattern) (3.12.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zc.lockfile->cherrypy->pattern) (67.7.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.22)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (5.3.0)
# Requirement already satisfied: autocommand in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (2.2.2)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (7.0.0)
# Requirement already satisfied: backports.tarfile in /usr/local/lib/python3.10/dist-packages (from jaraco.context>=4.1->jaraco.text->jaraco.collections->cherrypy->pattern) (1.2.0)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (2.7.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (2.18.4)

# %%
import whisper
import torch
import pyannote.audio
import subprocess
import contextlib
import wave
import datetime
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from pyannote.audio.pipelines.speaker_verification import PretrainedSpeakerEmbedding
from pyannote.audio import Audio
from pyannote.core import Segment
import gc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Listar archivos en el directorio especificado
directory_path = '/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/'
files = os.listdir(directory_path)
print(f"Archivos en el directorio {directory_path}:")
print(files)
# Out:
# Archivos en el directorio /content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/:
# ['Audio.mp3', 'Audio.wav']

# %%
import subprocess

def extract_audio_segment(input_path, start_time, end_time, output_path):
    """
    Extracts a segment from an audio file.

    :param input_path: Path to the input audio file.
    :param start_time: Start time of the segment in seconds.
    :param end_time: End time of the segment in seconds.
    :param output_path: Path to save the output audio segment.
    """
    try:
        command = [
            'ffmpeg',
            '-i', input_path,
            '-ss', str(start_time),
            '-to', str(end_time),
            '-c', 'copy',
            output_path,
            '-y'
        ]
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        if result.returncode != 0:
            print(f"Error during audio extraction: {result.stderr.decode()}")
        else:
            print(f"Audio segment saved to {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Error during audio extraction: {e}")

# %%
# Parámetros personalizables, en caso se quiera transcribir solo una parte de
# todo el audio.

input_audio_path = '/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio.mp3'
start_time_seconds = 5 * 60  # Minuto 5
end_time_seconds = 15 * 60 + 9 # Minuto 15
output_audio_path = '/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio_segment.mp3'

# Extraer el segmento de audio
extract_audio_segment(input_audio_path, start_time_seconds, end_time_seconds, output_audio_path)
# Out:
# Audio segment saved to /content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio_segment.mp3

# %%
# Función para transcribir

class AudioTranscriber:
    def __init__(self, path, num_speakers=1, language='Spanish', model_size='large'):
        self.path = path
        self.num_speakers = num_speakers
        self.language = language
        self.model_size = model_size
        self.audio = Audio()
        self.embedding_model = PretrainedSpeakerEmbedding(
            "speechbrain/spkrec-ecapa-voxceleb", device=torch.device("cuda" if torch.cuda.is_available() else "cpu"))
        self.model = whisper.load_model(model_size)
        if path[-3:] != 'wav':
            self.path = self.convert_to_wav(path)

    def convert_to_wav(self, path):
        filename = path.rsplit('.', 1)[0]
        new_path = f"{filename}.wav"
        subprocess.call(['ffmpeg', '-i', path, '-ac', '1', new_path, '-y'])  # Convert to mono
        return new_path

    def transcribe(self):
        result = self.model.transcribe(self.path)
        segments = result["segments"]
        with contextlib.closing(wave.open(self.path, 'r')) as f:
            frames = f.getnframes()
            rate = f.getframerate()
            duration = frames / float(rate)
        embeddings = self.get_embeddings(segments, duration)
        clustering = AgglomerativeClustering(self.num_speakers).fit(embeddings)
        labels = clustering.labels_
        for i in range(len(segments)):
            segments[i]["speaker"] = 'SPEAKER ' + str(labels[i] + 1)
        return segments

    def get_embeddings(self, segments, duration):
        embeddings = np.zeros(shape=(len(segments), 192))
        for i, segment in enumerate(segments):
            embeddings[i] = self.segment_embedding(segment, duration)
        return np.nan_to_num(embeddings)

    def segment_embedding(self, segment, duration):
        start = segment["start"]
        end = min(duration, segment["end"])
        clip = Segment(start, end)
        waveform, sample_rate = self.audio.crop(self.path, clip)
        return self.embedding_model(waveform[None])

    def save_transcription(self, segments, output_filename):
        with open(output_filename, "w") as f:
            for (i, segment) in enumerate(segments):
                if i == 0 or segments[i - 1]["speaker"] != segment["speaker"]:
                    f.write("\n" + segment["speaker"] + ' ' + str(datetime.timedelta(seconds=round(segment["start"]))) + '\n')
                f.write(segment["text"][1:] + ' ')

# %%
# Ejecutando para audio completo
transcriber = AudioTranscriber('/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio.mp3')
segments = transcriber.transcribe()
transcriber.save_transcription(segments, '/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio.txt')

# %%
# Ejecutando por un segmento del audio
transcriber = AudioTranscriber('/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio_segment.mp3')
segments = transcriber.transcribe()
transcriber.save_transcription(segments, '/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio_segment.txt')

# %%
# Liberación de memoria
del transcriber
del segments
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %%
# Visualizar transcripción

file_path = '/content/drive/MyDrive/SPEECH ANALYTICS/AUDIOS/AUDIENCIA/Audio.txt'

# Abrir y leer el archivo
with open(file_path, 'r') as file:
    content = file.read()

# Dividir el contenido en líneas de longitud fija (por ejemplo, 80 caracteres)
max_length = 120
lines = content.split('\n')
wrapped_content = []

for line in lines:
    while len(line) > max_length:
        wrapped_content.append(line[:max_length])
        line = line[max_length:]
    wrapped_content.append(line)

# Mostrar el contenido con líneas envueltas
for line in wrapped_content:
    print(line)
# Out:
# SPEAKER 1 0:00:00
# Esucida, luz antes de ella, la moneda afligó mi color, que a los hijos ambos se les puede dar eso. Escribe, escribe, esc
# ribe, escribe, escribe, escribe, escribe, escribe, escribe. A su sombra vivamos tranquilos, y al nacer por sus nubes del
#  sol, regocemos en la cura del evento. Te bendimos, te bendimos, te bendimos, te bendimos, te bendimos, adiós, te cajo,
# te cajo, te bendimos, adiós, te cajo, adiós, te cajo. Somos libres, seamos, no siempre, seamos, no siempre, y aunque nie
# gue su luz, su luz, su luz se casó, que faltemos a otro solemne, que la patria de tierra llegó, que faltemos. Somos libr
# es, seamos, no siempre, seamos, no siempre, que la patria de tierra llegó, que faltemos a otro solemne, que la patria de
#  tierra llegó. Viva el Perú! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! V
# iva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! Viva! cantando hasta un milo emoción. Que hoy tus hijos de jubilo v
# encidos cantando hasta un milo emoción. Por ella está de mon depasado que se adquiere sus almas y amor, que ahora lo vil
# ga e infunda en sus glorias reina tu barrio valor que perenne en los siglos ostentes tus razones, tus malas mil y alabar
#  a sus bienes remoses con mi alema de palma y cabrera. Y alabar a sus bienes remoses con mi alema de palma y cabrera. Y
# alabar a sus bienes remoses con mi alema de palma y cabrera. Con la escrupa del caso, por favor. Viva Huamco! Muchas gra
# cias por su asiento. Muchas gracias por su asiento. Muchas gracias por su asiento. Estamos en el área mágica de muchos h
# uamquenos y tenemos la dicha de estar en este principal centro de estudios que recibe esta importante audiencia pública.
#  Vamos a dar las palabras para que pueda dar una bienvenida el vicerector de la Fundación Herminio Báñez de Huamco, Dr.
# Pito Huamco O'Henry. Un fuerte aplauso para el doctor. Gracias. Gracias. Gracias. Gracias. Gracias. Gracias. Gracias. Gr
# acias. Gracias. Gracias. Muchas gracias a todos ustedes. Muchas gracias a todos ustedes. Señora Conferencista de la Repú
# blica, Isabel Medina de Mocir. Señor Vice-Primer, Vice-Primer de la Institución, Iván Ramos Osorio. Señores de los coros
# , de las diferentes instituciones que nos acompañan en la mesa de honor, igualmente nos dirigimos a los representantes q
# ue están aquí presentes de las instituciones vinculadas al sector adecuado, principalmente antiguo. Igualmente a todos l
# os presentes que han venido a diferentes lugares en el carrerito. El doctor Guillermo Bocante-Huayde, rector de la Unive
# rsidad, se encuentra en la sede de Lima en el bordo de la Universidad de San Francisco. El doctor, el doctor Luis Carlos
#  Bocante-Huayde, se encuentra en la sede de Lima en el bordo, exponiendo el presupuesto del 2025... Siente amor, tú vas
# a apoyarme en lo que sea la transmisión, ya? Vas caminando por todos los lugares. Ahorita acércate, acércate. A mi compa
# ñera, ella. Tú lo vas a grabar, yo le voy a pasar los micros. Acércate, acércate. Acércate, acércate. Acércate, acércate
# . No estás acercándote. No estás acercándote a la región, sino a los impactos que va a tener en nuestro país. Consideram
# os que la ley debe estar involucrada, debe estar vinculada, que esté tranquila a estas leyes. Debe estar involucrada, vi
# nculada a todas las problemáticas que tienen en la ANCA en esta región. Y de eso se trata precisamente que nosotros como
#  Universidad debemos darles también este servicio, por eso estamos aquí permanente como venimos aquí. Asimismo, el docto
# r Guillermo pidió a la zona congresista una ley de ley. Que exponerles esta rosa red sobre el parque científico tecnológ
# ico de Guam. Muestra la sala de la ANCA. Público va a hablar. Con su permiso, la zona congresista ignora y se divisa. ¿Q
# ué es esto? Bien. El 11 de julio del año 2023 se dio la ley 3126 que declara la Ingeniería Pública en Interés Nacional l
# a creación e implementación del parque científico tecnológico de Guam bajo la administración de la UNEDAD. La cual, que
# es un universitaria, asumió en el mes de octubre que se tiene que iniciar. Y asumimos rápidamente la manera de cómo eso
# es implementado. Porque, como pueden ver ustedes acá, esta ley tiene la finalidad de fortalecer la investigación del des
# arrollo tecnológico, la transferencia tecnológica y la innovación. Como también el incremento de la productividad, compe
# titividad y empresarial y darle un valor agregado a los recursos naturales y productos de la región centro y norte centr
# al del Perú. Como pueden ver, esta ley, que va a ser después sustentada por la congresista, se enmarca precisamente dent
# ro de ese parque científico tecnológico. Conchiquet, el ex director de la investigación de nuestro país, elaboró en el a
# ño 2019 un documento que va a generar lineamientos técnicos para parques científicos de productos en el Perú, el cual ti
# ene que elaborarse los planes maestros para esas cuatro etapas en una medida de tiempo. La primera etapa consiste en la
# implementación. Ya nosotros hemos aprobado la fase 1 planificación. El año pasado, luego de un año de haber trabajado a
# través de una comisión y luego de haber levantado las observaciones por los corrientes, Conchiquet aprobó la fase de pla
# nificación. Este año hemos venido ya coordinando con dicho organismo para elaborar el plan maestro pero del diseño del m
# odelo de este parque. Precisamente, el 2 y 1 que es el dios la prueba de la mañana se tiene en la reunión presencial en
# dichas oficinas para avanzar este tema. Tomando en cuenta la finalidad de esta norma se ha elaborado el sistema del ecos
# istema del Parque Científico Tecnológico Paraguay. Aquí participan actores muy importantes. Uno es este estado, el gobie
# rno central que tiene que ver con el tema del financiamiento de este parque. Igualmente el gobierno regional, los gobier
# nos locales, tanto provinciales como municipales, todo el sector empresarial de todas las actividades económicas de esta
#  región que pertenecen a diferentes sectores económicos, sociales, etc. Lo que buscan es este ecosistema es precisamente
#  gestionar la investigación, desarrollar la tecnología que permita generar innovación para llegar a los bienes y servici
# os de los ciudadanos. Y que eso que requiere empleo, impuestos, divisas y otros y que también nos pueda sustentar el des
# arrollo y el control social y que busque la finalidad de la población y mejorar sus necesidades. Por entonces, la parte
# del comercio peruano un poco más del 90% son mixtas. Menos de 4 o 5 trabajadores. De tal manera que el modelo de la econ
# omía de los sectores de los sectores tienen que ir dirigido a esos sectores. A ustedes por pequeños productores, pequeño
# s agricultores. Bien. En el Perú estamos pasando por un momento muy importante. Tenemos hoy de 6 a 7 grandes proyectos q
# ue van a dinamizar, a potenciar nuestra economía no solamente en América Latina sino en el mundo. He tomado este mapa de
#  un estudio que ha hecho la Universidad del Pacífico recientemente. Y como pueden ver se trata del puerto Chancay. Uno d
# e sus siete proyectos. Y el impacto que va a tener en esta área la generación de valor de una cadena de valor. Donde van
#  a involucrar a todos estos sectores que están aquí. Pero también la Universidad del Pacífico resalta dos grandes proyec
# tos. Uno, que es el parque industrial de El Cucarro. Que está organizado especialmente a mejorar en forma sostenida el s
# ector industrial para el efecto de exportación. Y el otro es el parque industrial de Ancón. Que está más vinculado a tra
# nsformar la estructura productiva de Lima. Y se cree que este parque va a incrementar el acero por ciento del PI para Li
# ma. También tiene colosines agroindustriales. Dos de ellos se encuentran en el País Ocual. Uno en Tingo Amarilla y otro
# en Amo. Nosotros hemos aplicado el parque científico de Guam. Miren ustedes la estrategia de nuestro parque. Porque la l
# ey dice tu ámbito es la región central y no central del Perú. Es decir, va más allá de la frontera de nuestra región. Y
# si eso no lo tomamos en cuenta seguiremos pensando en pequeño. Hoy esta ley nos da esa gran oportunidad. La pregunta que
#  nos hacemos es ¿estamos preparados en este caso como universidad? Somos cuatro universidades que ya hemos consensuado s
# obre este tema. Solamente quiero acá mostrarles tres laboratorios de los 142 que tiene nuestra universidad. Y que están
# ubicados en las carreras de agronomía, agroindustrias, industria, sistemas, por ejemplo, civil, salud, etc. Quiero acá r
# esaltar este laboratorio que recientemente hemos implementado en la facultad de economía. Investigación de mercado y bol
# sa de valores. Se ha hecho un convenio con la bolsa de valores de Lima y otra empresa que nos ha asesorado para la compr
# a de los equipos y las capacitaciones. Ahí ustedes van a tener, ya tienen hoy, información del comportamiento de los com
# presos de todos sus productos. Baby banana, de los verdes, cacao, café, cómo están las acciones en la bolsa de valores,
# la cadena de exportaciones, etc. Eso va a estar a disposición de ustedes a través de este parque científico-tecnológico.
#  Ya hace un año creamos el hub, el hub de innovación, que tiene componentes como Internet de las Cosas, aplicación digit
# al, traerá titular y aumentar co-working, pero dirigido justamente a las nifes, a ustedes, a los pequeños empresarios. Q
# uiero contarles una adepta que recientemente nos ha sucedido. Nos encontramos con la presidenta del Grupo AIM, que agrup
# a a 13 empresarios del sector turismo, pero que tienen el contento de artesanía de Jiros. Y nos contaron que ellos parti
# cipan en diferentes eventos, tanto nacionales, tanto de las industrias del exterior. Y que habían observado que los clie
# ntes pueden identificar rápidamente por el color o la forma con el diseño, que esas que se utilizan en el sector turismo
#  son de la manera que se utiliza en el sector turismo, pero no respecto a la artesanía de Guadalajara. Se acercó una per
# sona a comprar una blusa tejida a mano con bordados, y le dijo, que bonito, es de El Salvador, no es de Guadalajara, que
#  te atreves en la guarda. También se acercaron varios clientes que querían comprar, pero no encontraron una oferta diver
# sificada de productos. Ese problema lo tomamos y conversamos con las tres empresarias que pasan los últimos 60 y 70 años
# . Y se hicimos dos talleres. Uno, a través de la Dirección de Empuadras de Empresas, un taller sobre lugar y ideas, just
# amente para que puedan tener una solución a ese problema. Y dos, a través de IAP, hicimos un taller de introducción a la
#  inteligencia artificial, mostrando que es a través de nosotros cómo ellos pueden mejorar y seguir con la presentación.
# Hoy estamos apoyando a crear su propia página web. Y no solo es ese caso. Hemos tenido que construir unos robotitos que
# durante cuatro jueves en un colegio de 20 años decimos a los niños de la inteligencia, cómo nos pueden construir esos ro
# bots. Para su aprendizaje. Y cómo lo han tratado rápidamente. Son pilotos que queremos luego extenderlo a nivel de toda
# nuestra región. Y eso sería nuestro acorde a través del Paje Científico. Quiero demostrarles rápidamente algunas investi
# gaciones que hemos tenido realizando y incorporado justamente al sector de ustedes. En el caso del Canchán, tenemos la i
# nvestigación de comportamiento de cultivales del maíz para probar si el maíz es de Canchán. Ahí están los resultados de
# la Universidad llegando con los estudiantes, los practicantes, los tesistas, los investigadores. Preparamos el terreno c
# on los tractores, deseneramos ese terreno que los habían elegido. Luego lo hemos marcado y ahí investigaron tres tipos,
# tres variedades de cultivales en maíz. Y ahí están ya los resultados. Les adquirimos dos equipos importados que están vi
# nculados con el celular, acá hay dos aplicativos. Ya no tienen necesidad de esa planta que va al laboratorio, sino que e
# l mismo campo hace los análisis correspondientes. Ahí están ya las investigaciones. Sus resultados. Igual se hizo con lo
# s cultivables de alfalfa e incluso el de Canchán con tres variedades. Por supuesto que una de ellas es la que se adecua
# más, es más resistente. Y por tanto queremos hacer ahí transferencias cronológicas. El caso del Piochac, carbón vegetal.
#  Igualmente, entrenamos en el terreno, se hizo los trabajos correspondientes a escala de los laboratorios para conseguir
#  el carbón vegetal. ¿Hubo buenos resultados? Claro que sí. Mejoraron los rendimientos, la fertilización de la tierra, et
# c. Hemos recuperado el terreno y el terreno. El que con plasma de vegetales y cítricos se enganchaba. Estos dos últimos
# jueves han ido los estudiantes de la agronomía y sus profesores investigadores a continuar a continuar mejorando este ej
# emplo en carta de cítricos. Y ahora vamos a incluir otros que con plasma. El caso del alfalfa, el caso del y otros. Aquí
#  también los apoyaron los estudiantes del Instituto Masclán de Amun. Y también en Canchán hicimos un ejercicio experimen
# tal que se llama Sistema Inteligente Basado en Industria 4.0 o Manitra de Tensición en Procesos Agrícolas con el maíz mo
# rado a el ácido sulfúneo en Canchán. Que nos donó efectivamente la Corea del Estero que hicimos de edad para estos temas
# . Lo conocemos más que todo como el maíz morado negra tomasa. Tenemos aplicado inteligencia artificial TIPS como fue pre
# paramos el terreno les entregamos aquí los estudiantes estaban extendiendo las mangueras acá tenemos todo el equipo que
# hemos aplicado con un aplicativo de celular para que las 24 horas podamos hacer el monitoreo de este proyecto. Estos se
# han encerrado a 80 centímetros para el ton de datos viendo por roboteo esta es una antena que nos permite conectarnos co
# n internet eso todo lo pagó la universidad y ya para terminar trabajamos en fotos talpones inteligentes este es un proye
# cto que vemos suspendido porque tuvo dificultades el próximo mes lo vamos a reiniciar igual ha sucedido con la mejora ge
# nética del curso de movimiento criolo como pinto de perro 29. y tenemos otro problema el cruce de estos dos tipos de rov
# inos va a permitir que los que nalpan tengan mayor tamaño mayor combustión de carne y tengan mas crías al alma por ahora
#  hemos logrado que tengan 2 crías al alma muchas veces que tengan hasta 3 hoy hemos introducido mas que 50.000 soles par
# a que este proyecto tenga más crecimiento y que este proyecto siga creciendo y hemos adquirido hace 2 semanas que han ll
# egado 2 tanques para hacer incineración artificial porque estamos viendo que el proyecto va a emprender igual con el for
# raje verde hidroponico en este espacio hemos construido acá están los equipos hicimos una experimentación de trigo se te
# rmino acá luego acá se enjura y luego se va a hacer una recopilación de las banderas por ejemplo y por eso es que lo ina
# uguramos estamos como director de la universidad ahí pueden ver nuestra cámara oscura para la incineración aquí esta don
# de se procede ya a la producción misma acá los rotos cuyes mejorados es un complemento que ha tenido buenos resultados n
# osotros teníamos un promedio de 400 y tantos cuyes hemos bajado la tasa de mortalidad hemos ajustado el tamar el peso, e
# tc hasta el salón y acabamos de construir un garfón para 2000 cuyes mas y hemos hecho otra precia tenemos que ver que es
#  lo que es nos hemos contratado con la localidad de Urugopa de Alucnare ellos tienen una gran igual que los cuyes comune
# s que tienen ustedes aquí les muestran su alegría cuando han llegado a Cotos con sus hijos los hemos recibido en este ce
# ntro piloto les hemos explicado como es la cámara oscura para la incineración y luego como un fungusito y finalmente hic
# imos un compartir con ellos a los meses los hemos visitado ahí para ello pedimos el apoyo de los estudiantes de economía
#  al cual pertenezco a esa facultad los mismos estudiantes compraron banderas compraron balanzas electronicas y fuimos al
# lá lamentablemente nunca se la logro y a partir de ahí el bus no avanzo y tuvimos que ir allí y que bueno que eso suceda
#  para que los jóvenes vean como a uno se cargan los kilos y kilos de gasol que uno lleva a los fertilizantes que es una
# buena experiencia para los jóvenes y tambien para nosotros por supuesto ahí les hicimos unas clases simples de costos, i
# ngresos y gastos sencillo para que los puedan manejar y les hagan sus trampas de cuyas y lo que nos dio a la facultad el
# los ya estaban allá produciendo hidroponico con estos barbecitos pero como les hemos llevado banderas, estas banderas va
# n a reemplazar sus barbas y tambien les enseñamos como deben de ingresar sus cuyas en estas bandas electronicas y las tr
# abas como ven usan las barbas mas el complemento de los trigo que al final de la reunión los invitaron a que se hicieran
#  estos tratos de cuyo bueno esta es la propuesta que tenemos para guarnir es algunas imágenes de como debe ser el concep
# to de modelos de parque cientifico temporario si les hago un vistazo de la calidad gracias por ver este video gracias a
# todos muchísimas gracias muchas gracias por el conocimiento con nuestros aplausos muchas gracias antes de poder iniciar
# con las exposiciones del ministerio de agricultura que nos acompañan vamos hay que parar la la participación esa mañana
# lo empezamos al inicio mientras esperamos el inicio de este evento pero queremos recordarles que estas son las formas pa
# ra la participación esta mañana cuando luego de la participación de la congresista de la exposición de los vicinios cuan
# do el público en algún momento tenga que participar y en todo momento se aplican estas formas por favor presentarse iden
# tificarse el respeto ante todo cualquier palabra ofensiva que agreda a alguna autoridad lo invitaremos a retirarse se re
# spetará el tiempo asignado que se va a otorgar no se presten arestas y medios de negocio que no se apropiado y lo import
# ante el ser amado queremos reconocer también a los compañeros que nos vienen acompañando si quieren seguirnos en la pági
# na oficial de la congresista Elizabeth Merida y los que nos vienen acompañando esta mañana a continuación palabras de la
#  congresista Elizabeth Merida aplausos para ellos aplausos aplausos aplausos aplausos aplausos aplausos aplausos aplauso
# s aplausos Muchísimas gracias primeramente agradecer a Dios por estar presente en esta audiencia Buenos dias a todos los
#  presentes. Es un honor de darle la bienvenida en esta audiencia pública. Agradecer también la presencia del Vice Minist
# ro de Desarrollo de Agricultura Familiar e Infraestructura, a Gaya y Diego. Un fuerte aplauso. A esta vez también tenemo
# s la participación de Iván Ramos Pastor, del Director Ejecutivo del Proyecto Especial Alto Vallada. Un fuerte aplauso. U
# n fuerte aplauso. Elen Javi Parra Casallera, del Terente General de CERFOR. ¿Se encuentran presentes? Un fuerte aplauso.
#  Del Señor Segundo Enrique Regalado Garonal, el Director de la Autoridad Administrativa del Agua Vallada. Es bueno que e
# sté presente, por favor. Se pone en el pie, por favor. Se pone en el pie. ¿Está presente? ¿Está presente? Un fuerte apla
# uso. Un fuerte aplauso. El Señor José De Mora. Un fuerte aplauso. El Señor José De Mora. Un fuerte aplauso. El Señor Jos
# é De Mora. Un fuerte aplauso. El Jefe de la Unidad Sonal de Huamco, de Arro. ¿Se encuentran presentes? Bien. Bien. Bien.
#  Este... El Jefe de Arro, Mito Juan Santiago Vélez. Difer todo... in worsh � rijen y qué me da los ojos, conv submarines
#  tert languish en esta casa y decir bien alzhur madigni 바둥. Muchas gracias, por favor. Muchas gracias, por favor. De tra
# bajo en Eg compartir y también Alexis Marì. La Sra.시면 Flower Se le powser y yo, resulta que es igual. Los ojos bailando
# y al esto le dan Hойetbi no lo puedo olvidar. La Sra.su Palmas te pasan bien, ¿no? Y luego, ¿ounga? de la Cruz, del dire
# ctor del atraso de la unificación y ordenamiento del CERJOR. Yohan Delfín Baltasar Peña. Tambien empiezan a presentar la
#  club américa y contra la CERJOR... Regi venues 주aceutical e con la designación La tercera plena audiencia interna del C
# ERJOR. imato Antonio Garza Ramírez.. Dep fortress moriaquien participat. T animate la prosseccion política de la prematu
# re salecita Maria Antonieta Roier Danko祖 asa peigo庁 haza. de hoy tenemos la presencia de algunos alcaldes provinciales.
# Quiero que, si está presente alguno alcaldes provinciales, quiero saber, ¿el alcalde provincial de la Uricocha se encuen
# tra presente? ¡Fuerte voto de aplauso! Es el único alcalde que me parece que le importa sobre la problemática de la agri
# cultura de nuestra zona. Los alcaldes distritales, ¿se encuentran? ¡Chacabamba presente! ¡Chacabamba presente! ¿Está pre
# sente? ¡Pachitea presente! ¿El alcalde? ¡Mira! ¿Por qué está presente? ¡María! ¡Son alcaldes de los diferentes distritos
# ! ¡Porque! ¡Choras presente! ¡Los alcaldes de los centros poblados! ¿Se encuentran presente? ¡Muy bien! ¡Macuya! ¡Muña!
# ¡Muña! ¡Bolonesi! ¡Marabamba! ¿Quiénes más están presentes? Mira, estamos pasando lista de aquellas personas, le estamos
#  dando la bienvenida, porque este es un día muy importante para la vida de los alcaldes de la República, y es un tema mu
# y importante, justamente, que nosotros estamos haciendo esta audiencia pública, y a la vez, ya vamos conociendo quiénes
# son las autoridades que se identifican con sus pueblos. Porque nosotros, como ya congresistas de la República, conocemos
#  las problemáticas que viene teniendo la región Juanjo en la región de la República, y que nos da la oportunidad de que
# nos acompañen en la política y en la cultura. En ello, nosotros siempre vamos a dar el realce político y social para for
# talecer justamente nuestro trabajo dentro del marco de nuestras funciones de representación, de legislación, y de fiscal
# ización. ¡Muchas gracias! El día de hoy vamos a tener justamente la exposición de la ley 31933, que por el instante de l
# a ley, por estar en estado más intensa, que hoy se ve en tema de debate, representante al avance de este tipo hacia un d
# esarrollo de migrano que agoniza a la conservación ambiental con el progreso económico. Y, por último, vamos a tener la
# exposición de la ley 31933, que por el instante de la ley, nos se aplica a la comunidad de bottle Surprise, que por el i
# nstante de la ley ver casi sobre la comisión, en el que vemos a las comunidades y no vemos jak del voto internado repres
# entados, y el poderando justamente a las comunidades locales. Decirles que también es lamentable que, y se abre el exped
# iente técnico para empezar a trabajar sobre el redimensionamiento para la entrega de los signos de propiedad de todos nu
# estros hermanos campesinos de la zona de la Amazonía. A la vez también el compromiso que tiene que tener con todos los h
# ermanos agricultores de la zona altoandina, porque ellos tienen una problemática que es que han perdido sus sembrillos c
# on el friaje, con las heladas, que ha habido una inversión justamente que se ha dado. Y hasta el día de hoy ellos no pue
# den recuperar. Pero más bien tenemos el día de hoy la presencia del vice ministro con sus directores de la COE de PES na
# cionales y los directores de la COE de PES locales, donde vamos a tener diferentes compromisos y vamos a lograr resultad
# os cuando haya el trabajo articulado. Así como lo vamos a intentar. Y también vamos a tener el presidente del estado que
#  me ha precedido, el vice rector de la Universidad del Rio de la Pizarra. Tenemos que unir fuerzas para trabajar en coor
# dinación. Tanto el legislativo con sus leyes, el ejecutivo con sus presupuestos, los gobiernos regionales con sus presup
# uestos, los gobiernos locales, provinciales y distritales, tocando las fuerzas de la COE de PES. Para que se fiscalicen
# sus proyectos de canales de riego. Para que se fiscalicen sus proyectos justamente de acuerdo con sus programas que exis
# ten de los citocondos. Que existen una vez más, que suban por las zonas actuales el agua. Y para eso estamos. Y para eso
#  se hizo esta audiencia pública. Y para aclarar ciertas interrogantes de la gente que sigue por los medios de comunicaci
# ón frente al proyecto de ley que ya es ley y publicada en el peruano el 11 de enero del año 2014 de la 31-9-63. Eso tien
# e que... ...de terminar justamente en un acta. Porque veo que algunas autoridades piensan que en el pleno del comienzo s
# e apoyen las leyes y simplemente pierden su papel. Se tienen que hacer con resultados. Se tienen que ejercitar. Aquella
# autoridad que no lo quiere hacer, que se atenda a las consecuencias, que le puede venir... ...procesos administrativos.
# Y si es posible, tal vez procesos penales porque está creciendo contra el derecho al trabajo. Contra el derecho a tener
# una vivienda, etc, etc, etc. En ese sentido, damos la bienvenida a todos nuestros invitados y apreturamos este evento de
#  esta audiencia pública. Muchísimas gracias y que Dios los bendiga a todos. Muchísimas gracias. Como decía la arquitecta
# , Elizabeth y la reina, la Rosy. A continuación vamos a tener la participación del Ministerio de Desarrollo Agrario y Gr
# iego con sus diferentes viceministerios y direcciones. Vamos a invitar, y pedimos que todos para él, al viceministro de
# Desarrollo de Agricultura Familiar e Infraestructura Agraria, el rey de la arquitectura, a que le haga el reo. Un fuerte
#  aplauso para él, por favor. Quien nos va a hacer una primera exposición como parte de esta audiencia pública? . . Santo
#  остre Agostino. . . . Señores de la Comunidad de Mocilla, señores de las calles, señores de San Francisco, de la Univer
# sidad de Guadalajara, señores de las comunidades, el guadalajara, el guadalajara, el guadalajara, el guadalajara, señore
# s de la Comunidad de Mocilla, señores de San Francisco, señores de San Francisco, señores de la Comunidad de Mocilla, se
# ñores de San Francisco, señores de San Francisco, señores de San Francisco, señores de San Francisco, señores de San Fra
# ncisco, señores de San Francisco, parition bien ⌕ med Bombril spider el co Nast yourself sí los de backend no no no no n
# o no no no e o en la cual ahora los bosques de producción permanente son aprobados por la resolución ministerial del IAG
# . Además, como saben, esto antes era aprobado por la resolución ministerial del Ministerio del Ambiente, ahora están apr
# obados por el Ministerio de la Agricultura. ¿Qué avances tenemos al respecto? ¿Qué avances tenemos con la decisión perso
# nal de los representantes aprobados por los PPP de Huamara? Este es un primer avance que tenemos en relación a la admini
# stración del IAG. ¿Qué avances tenemos al respecto? El IAG ha decidido que esta reforma sea vial y, como les digo, ya ha
# y un avance indicado. En relación a la modificación del artículo 233, antes la modificación forestal era aprobada por la
#  resolución ministerial del IAG. Ahora, con la modificación del artículo 233, la modificación forestal está aprobada por
#  la resolución ministerial del IAG. Ahora, con la modificación del artículo 233, la modificación forestal está aprobada
# por la resolución ministerial del IAG. ¿Qué avances tenemos al respecto? ¿Qué avances tenemos al respecto? Principalment
# e, permite la desidentificación en aprobación, menos la microbiología. Al ser un solo sector, esto permite agilizar los
# trámites como más adelante se les ha indicado. ¿Qué avances tenemos? La aplicación de este artículo es automática. La ap
# licación de este artículo es automática. Esa es la base que se tiene a nivel de la ley. Los resultados de todo el depart
# amento de guardia son como están. Áreas naturales protegidas, 240.000 o 200.000 hectáreas. Ecosistemas priorizados para
# la conservación de la biodiversidad, 362.000 o 250.000 hectáreas. Y como son las estrategias especiales, en la reserva d
# e piedras, por ejemplo, las indígenas, en el alzamiento o contacto inicial, 44.453 hectáreas. Representa una superficie
# total de 748.000 o 170.000 hectáreas, que corresponde al 17.16% del área total del ámbito de desidentificación forestal
# del departamento de guardia. ¿Qué avances tenemos al respecto? Principalmente, permite la desidentificación en aprobació
# n, menos la microbiología. Y como son las estrategias priorizadas para la conservación de la biodiversidad, 362.000 o 25
# 0.000 hectáreas. Y como son las estrategias priorizados para la conservación de la biodiversidad, 362.000 o 250.000 hect
# áreas. Y como son las estrategias priorizadas para la conservación de la biodiversidad, 362.000 o 250.000 hectáreas. La
# primera disposición complementaria transitoria, la desidentificación forestal de los organismos de título sanitario. Se
# suspende la exigencia de desidentificación forestal como condición para los organismos de los títulos sanitarios. Esto,
# por dos años, siempre que el gobierno regional haya instalado los propietarios. Y por un año, el salario siempre existe.
#  Pero no funciona simplemente con un 2006 ingreso de desidentificación forestalíllista para sus títulos silentes. Y como
#  estamos encontrando así una знаvolidad Civil de Cusco, queremos administrar, y sumousemos el análisis de la situación c
# on una expresión del siendo y con dos competenciasbrush que compromete con des Vegetal Gobernado del Sistema Sanitario p
# ara los Poorfilms. El objeto de importante ser que no se aplica para los organismos con funciones venerables. Lo que hag
# o es combinar la eluerdo internacional colombiano con el juicio nacional racionado por mee raj states con tenían círculo
# s interna recientes junto con el señor Rubio Ro Romero. La procedening ro floja a todos los ac guide review de familiari
# zations en la investigación de este derecho en esta semana. por lo que se ha creado un proceso de la creación de los úni
# cos medios que van a impulsar la solidificación forestal a nivel nacional. En relación a la segunda disposición condenat
# aria transitoria, prohibición de abogamiento de títulos habitantes durante el período de suspensión de la existencia de
# la zona, solicitar primera disposición, no se acogerá títulos habitantes forestales de zona silvestre, en áreas que se e
# ncuentran en talleres de reconocimiento, educación o de aplicación de comunidades altas, concedidos territoriales, juego
# s de tratamiento voluntario o voluntad civilizada. De esta variante, si se respeta los convenios internacionales, se ase
# gura que los derechos políticos de los pueblos indígenas y comunitarios no sean registrados respetando los derechos nece
# sarios. Igualmente, en lo que corresponde a la única disposición condenataria final, que es tener disposiciones previas
# privadas de cuenta con títulos de propiedad, para constancia de posesión emitidas por la sociedad competente, emitidas c
# on anterioridad por la agencia de la gente. En la misma manera, las instituciones de la comunidad indígena y comunitaria
#  de la ciudad de México deben tener en cuenta que los derechos políticos de los pueblos indígenas, como la de la comunid
# ad indígena y comunitaria de la región, no son registrados en las páginas de los congresistas, sino que se establecen en
#  la orden de actividad a lo mejor. Aquí, el beneficio es que hay que cerrar los centros y sus modelos, desde el centro d
# el sur, y sus modelos, esto va a incidir en el proceso que se tiene para poder desarrollar el reconocimiento. Este proce
# so directamente incide en el diagnóstico físico legal, acortando su tiempo. La disposición condenataria final, la desinf
# ección de tierras, ya regla es el cambio de uso para actividades agroecológicas existentes. En este caso, se pone tradic
# ional el organismo adecuado para los precios privados. En los precios comunitarios de la región, la desinfección de tier
# ras mínima, que es el 30%, compensa de manera progresiva por áreas reforestadas o de conservación dentro o fuera del ter
# reno. Igualmente, hay que considerar que el conocimiento de la desinfección de tierras mínimas está adecuado en el 4º pa
# go del Título 38, dentro de las plantaciones forestales y fuera del título habilitado. Aquí, en el caso de la reserva mí
# nima establecida en el 4º pago, la obligación de 30% más a los dos existentes de tierras de la Sistema Agrícola y manten
# er la obligación de veredna o de protección. Consideraciones a tener en cuenta. Mediante el auto de fecha 20 de febrero
# de 2014, el Tribunal Constitucional admitió a través de la demanda de un Constitucionalidad sin respuesta por el Gobiern
# o de Andrés Martín contra la Ley 31973. En tanto no haya conocimiento del Tribunal Constitucional, corresponde al Poder
# Ejecutivo implementar la Ley 31973. La Ley 31973 Aplausos No aplica a las áreas donde se han otorgado derechos a concesi
# onarios forestales. El alcance es sólo para premios privados que cuenten con títulos de propiedad o constancia de posesi
# ón y homilías antes de la vigencia de la presente Ley. El CEPFOR puede determinar, a través de imágenes anteriores, si l
# a deforestación se lideró antes o después de la Ley. Son consideraciones a tener en cuenta, en torno a lo que correspond
# e a los alcances y beneficios de la Ley 31973. Esta es una primera parte de existir algunas inquietudes o consultas. Est
# á todo el equipo técnico que va a poder brindarles con mayor detalle los alcances y particularidades de cada forma. Esta
#  segunda parte está orientada a poder dar a conocer, mostrar el trabajo que desarrolla el Ministerio de Agricultura y Ri
# ego aquí en la Región Huamco. Estas son todas las entidades del Ministerio de Agricultura que tienen presencia en la Reg
# ión Huamco. Es importante la discusión, es importante tener claridad de qué trabajos desarrolla porque muchas veces, por
#  desconocimiento, no se aprovechan muchos de los productos o servicios que vienen del Ministerio. Y como vamos a ver, a
# lo local, el PSI, ANAS, ENASA, el CEPFOR, el Proyecto Especial Alto Guayaga, el MIA, el CERRE, el CERRE Tornadoras, así
# como el MIGUIDEAS, tienen proyectos y vienen desarrollando actividades aquí en la Región. La Comunidad Guayana, aquí en
# la Región, brinda lo que son los derechos de uso de agua, la licencia de uso de agua para el sector agrario y otros usos
# , la delimitación de la párgama final en ríos y lagunas. Esto permite velar para que no se generen limitaciones en los c
# asos de ríos, en algunos casos, si se generen los problemas que ya conocemos en época de densidad de río. El fortalecimi
# ento de las obligaciones de agua. Capacitar a la Junta de Villalba para que cumpla el rol de operadores y campos. Es muy
#  importante que haya una buena organización que esté totalmente fortalecida para que la infraestructura que se va entreg
# ando pueda ser operada correctamente, que tenga el tiempo de vida útil que se ha previsto con inversiones. Son inversion
# es marquiosas que se desarrollan y muchas veces, por el tema de la operación o mal mantenida, el tratamiento lamentablem
# ente no brinda el beneficio que debería brindar la población. El SENASA tiene presencia también en la región Huánuco a t
# ravés de sanidad de animales con vacunaciones contra el carbunco, sintomáticos, monitoreo y vigilancia de influencia rea
# l, vigilancia y control de peces por siquiera, y atención de cerebrales notificados. Asimismo, en sanidad vegetal, atenc
# ión a importación y exportación de tránsito internacional de vergas y agropecuarias, la vigilancia y el monitoreo de cul
# tivos fertilizados, la inocuidad alimentaria a través de la fiscalización de insumos agropecuarios, verificación de la f
# echa de vigencia, productos de agricultura, productos adulterados, productos de contrabando, supervisión de actividades
# de producción orgánica, capacitación de buenas prácticas de higiene y manipulación de productos en mercados. Todas estas
#  actividades que desarrollan el Ministerio de Agricultura a través del SENASA aquí en Huánuco, pero que muchas veces no
# los visibilizamos, y esta presencia del Estado, no se ve, no se ve bien aquí, no se visibiliza. Es importante tener en c
# uenta que sí están presentes. Igualmente tenemos el INEA, o la Estación Experimental Agraria Canchada, y 30 servicios en
#  innovación agraria, con la investigación y desarrollo tecnológico a través de artículos manuales y catálogos. Esta inve
# stigación es difundida a través de estos documentos. La transferencia tecnológica, adopción de nuevas tecnologías desarr
# olladas por la ingeniería, tanto en ganado como vino tropical, cuyas desplazan, y cultivos como maíz morado y otros. Y l
# o que es la extensión agraria a través del entrenamiento para la formación de extensionistas para mejorar la producción
# agropecuaria. Capacitación, brindada de personal que luego va a permitir al campo difundir, y transmitir todo el conocim
# iento que se va generando a través de la investigación. Y sí, ya les es muy importante poder interrelacionar con la acad
# emia, y poder transmitir todos los avances que tienen y generar nuestros espacios también con la universidad. Igualmente
# , el CFO, a través de servicios de reconversación, recuperación de ecosistemas preparados, conservación, presentación y
# recuperación de las zonas intensas. En conjunto, desarrolla todo lo que es la gestión forestal y el desfondo de los silv
# estres. Sin adicción a la exportadora, ninguna de las dos guías, oye algo a los productores agrarios, organizamos a trav
# és de accesos locales, nacionales e internacionales. Realizamos la gestión de los recursos, realización de pruebas de ne
# gocios a productos de sierra y selva, instrumentos de centros de copio de diferentes cerdos de cultivo en la región Huán
# uco. Igualmente, apoya a las organizaciones de la Cañada de Papas, Agua y Malto, de café y pescado. Asimismo, nadie es d
# esastricado de morir para el desfraude exterior, con trabajo articulado con la Cámara de Comercio de Huánuco. Así es com
# o tenemos la presencia de la CUCUCA, que viene trabajando en la implementación del Plan Municipal Nacional de Asistencia
# , a lo cual tiene presupuesto de 4 millones de pesos por domicilio. La implementación de asistencia para el economía y l
# os servicios por vacío, para esta actividad se encuentra con un presupuesto de 2 millones de pesos por domicilio, que es
#  de 4.548 millones de pesos, y el proyecto de la Cámara Índica, que tiene un presupuesto de 2.011 millones de pesos por
# domicilio. A continuación, vamos a ver las actividades que se tienen que desarrollar en la región en relación a estas in
# tervenciones. El Plan Municipal Nacional de Asistencia detiene la vocación de aplicación mundial que se entregarán de ci
# entos de que se beneficiarán de cientos de productores. Con la acción de ejecutes de final se entregarán 1.042 que benef
# iciarán a 1.042 productores y 104.200 cabezas se entregarán. Igualmente, se tiene la vocación de conservación de cobajes
#  que beneficiarán a 1.025 productores. La vocación de CIV de Sevilla del Paso es un privado. Se entregarán 1.775 que ben
# eficiarán a 1.775 productores y 1.030 salidas. Se tienen también en relación el monto a la temporada ganadera. Se implem
# entarán cinco permisos que beneficiarán a 100 productores y 12.000 cabezas de ganado. Estos permisos están conectados pr
# incipalmente a los que están dispuestos tanto a edades como a fiat. Monto para protección ejecutiva se implementarán a 2
# 50 productores y en especial a 250 productores. Como ven, el plan de edades tiene diversas actividades que se vienen a i
# mplementar en la región. Asimismo, en guardo y prostitución se generarán a los que están en el mercado. Se tiene a travé
# s de la la comercialización de guano de listas y se tiene previsto comercializar 564 condenadas de guano de listas que b
# eneficiarán a 763 productores. Asimismo, la instalación de pasos de semillas de pasos cultivados se instalarán en todos
# los clientes a los que están en pasos cultivados y beneficiarán igualmente a otros clientes. Como ven, esta es la interv
# ención que tiene AgroGrad en lo que corresponde a la actividad de estando en distrital en edades de gas. Sin embargo, ta
# mbién se tiene actividades orientadas a la comercialización de suelos. En esta actividad las mesas que tenemos son asist
# ir a 290 productores de 375 hectáreas como la institución de prácticas en conservación del suelo. Igualmente, a través d
# el proyecto de la escala hídrica la recuperación y o construcción de tres cotas, construcción de cinco rechegolos, recup
# eración y manejo de 200 hectáreas de praderas, construcción de un medio que no le puede dar la introducción para poder b
# eneficiar a los ciertos pasos de los productores. A nivel de la estructura de la escala se tiene programado elaborar la
# liquidación inicial de esta escala para la recuperación de canales de combustión que beneficiaron a 553 productores en 5
# 57 puntos de edad. A nivel de la estructura del riego a lo local tiene la liquidación de tres obras en sistemas de riego
#  y también la elaboración del expediente técnico que sacro de obra del sistema de riego AXS. Y el programa de su secreta
# ria de delegaciones igualmente tiene seis publicaciones importantes en la primera reunión con una inversión de 24.8 mill
# ones como presupuesto total y el presupuesto asignado para el proyecto de la estructura del riego en el riego de 167 pun
# tos de edad. En la segunda reunión se presentaron dos proyectos de riego en las seis obras de la estructura de la estruc
# tura del riego de la estructura del riego en el riego de la estructura de la estructura del riego y de la institución qu
# e está previsto para agosto 2014 y de esta manera se puede empezar hacer una entrega del proyecto Del mismo modo, el pro
# yecto de sistema de riesgo parcialario del grupo de gestión empresarial Saria Palma, detiene que a culo de 2014 la Funda
# ción de la Federación de México, en septiembre el registro de viabilidad del proyecto, y obtuve la gestión de recursos p
# ara poder iniciar el proyecto, y el inicio en enero de 2014. La elaboración del expediente sigue con una prevista para e
# l 20 de diciembre, y para mayo la culminación del expediente e inicio del proceso de gestión de recursos, de tal manera
# que a agosto 20 de diciembre se esté iniciando la gestión de recursos. Esto es incidencial porque dentro de lo que se es
# tá haciendo en el proyecto, dentro del pedido, había muchas consultas de los gobiernos locales en relación a proyectos y
#  su estado de extensión. Por eso que se han incluido estas tánicas que lo cubre ya en el estado situacional de estas int
# enciones que tiene el presidente. Y lo que corresponde al sistema de riesgo del investigado, para el grupo de gestión em
# presarial, cuya parada es a Rafael, en la dirección principal del decreto, se tiene prevista la administración de un pro
# yecto nuevo para la gestión de recursos, y la incorporación del expediente de la red de riesgo. Se tiene prevista la adm
# inistración de la gestión de obras para octubre 20 de diciembre. De lo que corresponde al canal de la zona de Chihuahua,
#  la inversión se ha dado en 8.3 millones para 1.968 familias, 350 hectáreas, aquí se viene trabajando lo que es el levan
# tamiento de observaciones, la visita a campo, y de tal manera que a julio se tiene allá el pronunciamiento internacional
#  en relación a este proyecto. A julio de este 24 se tiene prevista la notificación a la red municipal sobre el pronuncia
# miento del levantamiento de observaciones en el periodo de febrero. Aquí lo que se trabaja es una... una revisión, pero
# también las observaciones son levantadas con la asistencia técnica, y moverse la dirección oriental, se observen los exp
# edientes, y pasen en tiempos detenidos, y vaya en reglas, por supuesto, como he dicho, la intención es que una vez haya
# observaciones del diseño, estas observaciones puedan ser levantadas con la asistencia técnica del equipo técnico del sec
# tor, en este caso, el EPS. De este modo, se va a iniciar el programa nacional de riesgo del fisiado, o el Banco Mundial,
#  ese proyecto importante, que va a tener una duración de 5 años, con dieta sin totalidad, todavía en concentración, con
# un monto de 448 millones, y se van a intervenir en 19 regiones, para beneficiar a 7.767 países, y atender las requisitas
#  agrícolas de 8.012 calles, como les digo, en 5 años, aquí se tiene 5 proyectos en la región... en la región... en la re
# gión Guayuco, con una inversión de 12.65 millones. Igualmente, tenemos agilidades por lo que es servidores, y en el depa
# rtamento de Guayuco, se tienen conectados 45 planes, por 2.9 millones, para beneficiar a 1.259 productores. La ejecución
#  general del negocio, tenemos 37 planes de negocio, con 900.000 soles de concentración, para los 266 productores. Esto s
# e encuentra hasta el 34% de beneficios. Tenemos lo que es la construcción de cosas, a través de cerros únicos, como ven,
#  en Guayuco tenemos 30 cosas, de formulación, en un bloque 1, que van a beneficiar a 313 familias, y va a haber, y se co
# ntempla, y se convierta, una reserva alérgica de 2.979 medios públicos, para beneficiar 1.500 hectáreas. A su vez, va a
# permitir la creación de empleo en por alias de la zona, con 8.750 plantas. Estas actividades, tienen también una cartera
#  de inversiones, en el 20 de dicuatro, son 20 cosas, con un módulo de inversión de 4.016 por centímetros, para 460 famil
# ias beneficiar, y el volumen de recarga, en este caso, es de 700.000 metros cúbicos, para la moneda de, 1.036 hectáreas,
#  con la generación de, 10.128 portales de trabajo. De manera general, se tiene igualmente, a nivel nacional, la particip
# ación, en la octava media de propiedades oficiales, en el 20 de dicuatro, y este, ya no se beneficiará en cuanto, en el
# mes de noviembre, se beneficiará, la participación, de 20.000 productores de café, a nivel nacional. Yo creo que, este e
# vento, va a dar ganancia, y va a permitir impulsar, a un mayor, la producción, de café, en la región. Así que, este es u
# n evento importante, y el cual, va a seguir trabajando, en su implementación. Se convocará, a productores de cacao, del
# Perico Huano, para promover su participación, y el salón de cacao y corporales, en el 20 de dicuatro, en la octava media
#  de propiedades oficiales, en el mes de noviembre, en el mes de dicuatro, a nivel nacional. Así que, la preparación, deb
# e estar, en la fase final, porque, el evento, es escudo especial, ¿no? Y, creo que, seguirá, con razón especial, porque,
#  como sabemos, creo que, en este caso, el cacao, está alcanzando, un precio, histórico, nunca antes, que la participació
# n, de cooperativas, nacionales, de huano, para su participación, en el contorno de calear, de la ronda de cacao, del Per
# ú, en el día de dicuatro, que finalizará, en octubre. Definidamente, este es, es un, un evento, que va a permitir, mostr
# ar, y, darle, un especial, especial, a los agricultores, de la región. Ya voy a estar, en este momento, en este momento,
#  a la de la Cámara de la Seguridad. A continuación, la asociación, y en el financiamiento de la octava edición de la cas
# a de 2024, se van a financiar a 1.000 productores con cursos de la Universidad de la Universidad de la Universidad de la
#  Universidad. Como vemos, hay actividades que también son franquizables a nivel del país y permiten promover, motivar e
# impulsar la actividad de la aldea, sobre todo ir trabajando en la alcaldía para poder conquistar el trabajo social. Igua
# lmente, se invita al asistente de la dieta, el director de la alcaldía, para que nos denejo en misa técnica la práctica
# CABA, que el proyecto de comercio de los barrios va significando elevar el estado del clima, para mejorar la resistencia
#  y que todos los presentes, todos los CABA, como Nóclas, como Ezequiel, se convida en una idea para la gestión de canes
# de rojo, que es la capa para los procesamientos, y se realiza apoyo en el cielo para la construcción de las ciudades de
# la barbara y el mar. Y bueno, se subió la participación de la Secretaría de la República de la Nación, se presentó el se
# gundo caso de la crisis de la pandemia y le decimos que la mitad de la promoción comercial de la huerta de queso y demás
#  es de la comida. Y bueno, la mitad de la promoción comercial de la huerta de queso es de la comida. Confirió en un inst
# ante los concursos macrocriminales para incentivar la producción de los funcionales. El concurso macrocriminales de 2021
# ...
# l. Quisiera, por favor, señor congresista, que el viceministro, por su intermedio, nos extienda la mano y la aceptación
# el beneficio de los agricultores. En la fecha, me quedo con un favor. Mientras entrega el documento, se traemos de una c
# omunidad congresina de muchos. Buenos señores, que estén bien, y 們 niet con membres deissy voci is verdad que línea diri
# gente de la comunidad a usted, señoras y señores, que necesito representar a gran ministro, el presidente de las autorid
# ades. Señores, primero les voy a presentar a este miembro, yo quiero representar a los señores. Bueno, señores autoridad
# es, si me conocen de verdad, guapo, pues estamos conversando con los autoridades, señores. Voy a presentar a los preside
# ntes. Muchísimas gracias a la comunidad que aprecian a mi mucho. Escucharemos a continuación, nos visitan desde el área
# de Córdoba. Va a presentar un memoriaje. Un paso adelante, por favor. Presente. Buenos días, buenos días, señoras y seño
# res. Yo vengo, señor ministro, viceministro, vengo de la autoridad de aquí de Córdoba, de Córdoba. Somos un grupo de 20
# mujeres que estamos, o estamos, que hemos comenzado un área, área de aso, que hemos comenzado a recibir un plan de prese
# ntar. Pero así como saben, estamos siendo invalidos, amenazas a todos, a la población, y las autoridades sociales que qu
# ieren hacer un proyecto encima de la organización. Y nosotros queremos, señor. Que se reconozca nuestro trabajo de siete
#  años. Hemos intentado dar algunas que se están produciendo. Y la zona es bien difícil. Nosotros hemos tenido que cargar
#  agua para cargar nuestras plantas. Un cerro. Entre mujeres y mujeres, salgando galones y aquellas de agua. Y yo quisier
# a que se reconozca mi conversación. Muchísimas gracias. Señor memoriaje, por favor. Muchas gracias. No. No nos vamos a r
# obar más, señor ministro, funcionarios del Ministerio de Agricultura. Se han entregado todos los documentos que trajeron
#  desde distintas comunidades campesinas y desde los lugares más recuérditos del desarrollo. Hoy hay que destacar la pres
# encia de un solo alcalde provincial. Cuando fueron invitados todos los alcaldes provinciales. Y vamos a hacer la partici
# pación de alcalde provincial de La Urgolla. Señor, si es por favor. Está bien difícil. Dos minutos. Señora Cárdenas. Muc
# hísimas gracias. Gracias. Muchísimas gracias. Muy buenas tardes a todos. Primero agradecido con Dios. Gracias. Por permi
# tirnos estar en esta audiencia pública. Muchas gracias. Con precisa, precisa determina y reconocimiento por este acto pú
# blico. Y bien en contra de la actividad. Y en contra de la actividad a los espacios ministeriales. Es especial caminar.
# Señora Vicentizo. Tengo ustedes muy buenas tardes. Y al mismo tiempo al equipo técnico de todos mis ángulos. Eh, he podi
# do desear que usted recién ha sido nombrado un necesitado. Y he podido escuchar las diversas necesidades del ámbito de l
# a zona de la ciudad. De la zona albaniña y de la zona amazónica. Casi todos coincidimos, Vicentizo. Y todos tienen múlti
# ples territorios. Que les están haciendo llegar. Y eso es en base a la nueva decisión. Y me involucro como autoridad pol
# icial. A la nueva decisión de los gobiernos distritales. a la nueva creación de los gobiernos provinciales y a la nueva
# creación del gobierno regional, pero con distintas peculiaridades. En el caso del gobierno regional tienen presupuesto,
# pero hay distritos que no cuentan con presupuesto. Y de razón por la cual no podemos acceder grandes demandas si usted a
# hora lo está viviendo en el sector agrario. Felicitable el tema de la ley y aclararlo, viceministro, necesitamos que dig
# a, nos diga, cuándo iniciamos esta legislación. Han venido presidentes comunales, han venido dirigentes de la zona amazó
# nica, de la zona latina, a lo cual represento, y necesitamos saber que el equipo técnico en la articulación terminal y c
# on el PEC es el caso o lo que corresponda, cuándo hacemos el trabajo de trabajo. Ministro, recibo también el poder de sa
# ludo a nombre de la comunidad central, de alcaldes distritales y provinciales. Hay diversas necesidades, no las voy a de
# tallar, pero sí mi preocupación fundamental es la misma. Hay partidas desgraciadas que están reportadas a la Reconciliac
# ión. La finalidad no es ejecutar nosotros, sino que ustedes mismos lo ejecuten. Por ejemplo, si no todos, Magros, La Ori
# coya, Jesús, Magros y todos los hijos de la zona latina, necesitan que no todos. Y es una partida de responsabilidad que
#  ustedes de alguna manera se han hecho. Y siempre he hecho mil referimientos a la Rural y no estamos satisfechos. Nosotr
# os vivimos de la ganadería, pero la ganadería nos mata el viaje a la zona latina. Los supervisos, mis servicios. Como pl
# an piloto del año pasado, hemos ejecutado 20, que sean algunas partidas. Son partidas de los responsables que debemos po
# ner el mayor énfasis a ello. Necesitamos servicios para todos los trabajadores, necesitan que lo crezcan. San Miguel de
# Gauri, Baños, Rondos, Gilead. Necesitan los servicios y lo más primordial, cumple con el requisito de que? De comprar un
# a letra de regla y de estar más de 2.500 sobre el nivel de la edad. Mis servicios, están más con ustedes. No es que no t
# engan recursos. Trabajemos para el 25-25, tal vez no lo hicimos esta vez. Pero al 25-25 tenemos que hacer mis servicios.
#  Nos oculto con necesidad mis servicios. Tenemos un proyecto en el ámbito de desarrollencia en una zona minera. Es el di
# strito de San Miguel de Gauri. Que hemos compartido así. La 24-82-55. Necesitamos 24-82-55. Mi preocupación como autorid
# ad local ha sido tratar la comunidad médica. Y luchar contra la convivialidad favorable. Necesitamos articular el financ
# iamiento de los derechos médicos y los seminarios ecológicos de JORDA. Porque quizás la comunidad necesita riesgo. Es un
#  proyecto por más de 14 millones. Que va a tener buena cantidad de sectores para el río y el binario de la provincia. Si
#  miran el caso, les da también el distrito de Cochabamba, San Rafael, y la provincia de Manjubiá. Proyectos que ya tiene
# n algo a nivel de calidad. Tienen opinión favorable con parte del sector. Mis servicios. Son un proyecto que va a ser de
#  reactivación económica. Y lo más importante. Solucionar el tema de agua para el río y el binario de la provincia de Bor
# icua. Hemos conversado. Hay alguna discusión con el CISA. Hacer llegar esa necesidad. Yo sé que el CISO finanza, pero sí
#  articula. Por ser de necesidad pública. Ayúdanos a actuar. Porque lo más difícil es trabajar en la propiedad técnica. Y
#  este año y meses hemos podido lograr la propiedad técnica. Y desestaco la condición a través de los secretarios y los g
# obiernos de la propiedad. Hay varias necesidades. Vamos a seguir articulando. Agradecer por ese espacio público. Que a t
# odos les está presente. Hay residentes comunales que han hecho llegar su apreciación, su necesidad. Hay obras a realizar
# . Mis servicios también les comentaba. En el distrito de Baños tenemos una obra para el SAR. ¿Qué hago en Baños? El SAR.
#  Desde el 1 ha sido el compromiso. Acatemos el IVA. Acatemos el BAÑO. Tenemos ahora el gran riego para el SAR. Ayúdanos
# a hacer el compromiso. Yo sé cómo hacer la decisión. Pero necesitamos una decisión prioritaria. Y el ICETE lo más pronto
# . Muchas gracias. Y no lo quiero cansar. Gracias a todos. Muchísimas gracias al alcalde de la Huempocha. Quien es, perdó
# n, el último alcalde provincial. Preocupado por el tema de la región gubernamental. Vamos a, antes de la participación,
# todos hoy vamos a escuchar. Pero los alcaldes y licenciatales, les pongo el pie, por favor. Para reconocer su presencia.
#  ¿Qué alcaldes y licenciatales han quedado a hacer esta obra? Vamos a escuchar. Vamos a escuchar. Vamos a escuchar el IV
# A. Por favor, nos apoyan a sacar el micrófono. Sí. Bueno, en primer lugar. Muy buenas tardes a ustedes, hermanos. De reg
# ión amazónica. Y hermanos de zona amazónica. Ministro, viceministro de la agricultura. Señor pobrecista de la región gub
# ernamental. Y más funcionarios presentes. Soy alcalde del distrito de Chukis, de la provincia de Tocenayo, Gubernamental
# . Y agradecer por ese evento que han realizado. Mi petición, mi solicitud que soy. Para poder solicitar la culminación d
# el proyecto de instalación del canal de irrigación del distrito de Chukis, que es más de 20 kilómetros. Este proyecto ha
#  llegado. Ya pasó más de 14 años. Paralizado. No se ha concluido el proyecto hasta hoy en día. Hay mucha gente, muchos d
# e los hermanos del distrito de Chukis. Ya no están presentes. Soñando tener este canal de irrigación. Que va a beneficia
# r más de 9000 habitantes. Años pasados. Nosotros hemos sido declarados. Por estado de emergencia del Sistirio. Y muchos
# de nuestros hermanos del campo han perdido su producto. Nosotros. Como Chukisinos pedimos. Que ese pedido que se ha gene
# rado. Para poder solucionar. De alguna mesa técnica. Con. Con el ministro de agricultura. Y con el director del PSI. En
# la ciudad de Lima. Para que ya. Termine ese proyecto. 100%. Que va a dar servicio a la población. Es un proyecto soñado.
#  Anhelado por la población. Que supera más de 32 millones. Eso es que sois tú. Señora progresista Elizabeth. Apóyame. En
#  la ciudad de Lima. Y esta semana que viene. Voy a solicitar una mesa técnica. Yo desde aquí le pido. Apoyo a usted. Com
# o máxima autoridad del ministro de Chukis. Muchísimas gracias a todos ustedes. Muchísimas gracias al alcalde de Chukis.
# Hay un alcalde distrital más. Alcalde distrital. Ya, ya lo escuchamos. Al alcalde. No a mí. En breve. Señora alcalde. Sí
# . Voy a hacer el uso de la mesa técnica. Sí. Voy a hacer el uso de la palabra por la segunda vez. Una vez más agradecien
# do a esta reunión. Que se llevaba a cabo durante la mañana. Sé que se han sacado buenas conclusiones. Podría escuchar el
#  trabajo. Y el discípulo también. Nuestra señora progresista. Y a la vez también quiero partir breve con esta premisa. Q
# ue el ser social determina la existencia social. Y ambos determinan la existencia social del hombre. En ello pido tambié
# n más condenación a nuestras autoridades regionales, comresales. Más unidad de trabajo. No hay que llevar adelante esas
# viejas sentencias de los más pobres. En ese momento. Homo humis lupus. El hombre es lobo del hombre. Hay que dejar pasar
# . Hay que escuchar las autoridades. Hay que hablar con bastante respeto. Y yo como alcalde del distrito de Macachisco. S
# iempre estoy preso y llamo a colaborar. A contribuir. Pero solo no podemos hacer nada. Ya desde que decí que somos un di
# strito pequeño. Con bajo común. Y los que querían hacer un trabajo articulado. Tenemos que coordinar con los progresista
# s. Coordinar con los órganos de gobierno. A nivel indígena. Y hace momentos. Entregué mi ficha técnica al viceministro.
# Referencia de camarada Diego. Para el CISPAM. Entonces. Estimada comarca dista. Espero pues. Su anuencia. Que nos apoye.
#  A que esto se haga realidad. Ya que la expediente está determinada. Ya les dije. No se puede hacer nada. Tenemos que ha
# cer este trabajo. Juntos. En conjunto. Porque no tenemos el presupuesto. Estoy agradecido. Por esta reunión. Y sobre tod
# o. Pues. Este proyecto. Esta ley. Por estar. Las 31. 9. 73. Sé que va a ser beneficiado. A todos los que actuamos en el
# campo. Hay que entender bien. Hay que tener bien. Esta directiva. Para poder seguir trabajando. Muchas gracias. Muchísim
# as gracias a usted. Vamos a ver al representante del municipio de. Ya nos escuchó. Ya nos escuchó. Ya nos escuchó. Ya no
# s escuchó. Ya nos escuchó. Ya nos escuchó. Ya nos escuchó. Ya se león. D 같은데 eso. Ya, y luego en la sesión general ya no
# s escuchamos a las staves de Sobre las Marinas. Señora, yo le agradezco un albúmica, señor, discípulo, ministro, una déj
# à sabiusa cultura. llegó a la stympat Stillandould. Señor viceministro metaphísico,aininga centenaario del municipio de
# Landis. La verdadera basura cuando tuviste eliek infundación benutrada. La honestidad moderna exterior media de todo el
# municipio, la que gana descanso poriğo. Supuestamente. Sin embargo, no está en su derecho. Lo que ustedes dagegen, en se
# gundo lugar. ¿Cómo están ustedes referral? De este nuevo y una vez que manHHH Forward to징 Console of Officers, una queen
# bien. a través de la congresista hacer la entrega del expediente al Ministerio de Agricultura porque hace 14 años ese ca
# nal de naciones llanas se encuentra abandonado. Queremos, señor viceministro, su apoyo. Queremos que esa hoja sea la rea
# lidad pero no solo en llanas. La realidad se halla en las cuatro provincias altoandinas. Prefiero que se haga la haciénd
# ola de agua y lo mismo que tenemos los canales de río. No me dejo mentir el presidente o el señor secretario de la provi
# ncia Caula, que no tiene canal de río. Jesús tiene canal de río. Quiero palmas, tiene canal de río. Rondos tiene canal d
# e río. Ningunas. En Tierra Urca, ¿quién tiene? Ovas, tiene cama, tiene choras, tiene río y avenido. No las tiene. En los
#  que fallo, ¿quién tiene? Llanas, ¿quién tiene? Pachas, ninguna. Por eso, ahora que en noviembre se va a abrir el primer
#  acuerdo de Chalucaya, los que somos altoandinos, ¿quiénes vamos a vender? Si no producimos nada, nuestras llanas están
# vacías. El agricultor que hace se va a lavar. Se va a lavar. Se va a lavar. Se va a lavar. Estamos abandonados por años.
#  Por años. Y yo sé que el plan del consenso de Washington que se está utilizando, donde pasamos de un gobierno populista
# , heterodoxo, y ahora estamos viviendo un gobierno neoliberal, neoliberal, ortodoxo, ¿para qué estamos trabajando? Para
# los que rima y los que van a comer. ¿Cuánto hay de la ley que nos favorece los otros en el campo? No habrá tampoco. Pero
#  agradezco a la congresista que me ha enseñado y he estado conversando con su asesor, el señor doctor Chumka, y a través
#  de eso, estos documentos ya se llevó a los periodos de agricultura. Señor viceministro, le pido de todo corazón, ayúdan
# os, que esto se haga realidad. No solo en Llamas, sino en esas cuatro provincias. Muchísimas gracias. Si quisiera termin
# ar con esto, ¿te lo tiene? Yo lo tengo. Ok, bien. Los pueblos no son grandes por el tamaño de su territorio, ellos son g
# randes cuando sus hijos hayan alcanzado una conciencia moral, que los hagan dignas de civilización. Eso nos está marcand
# o, sí, pero con el acuerdo y con la idea de que la gente es una sociedad, de la integración de las instituciones, de las
#  organizaciones y al campo, seremos diferentes. Muchas gracias. Muchas gracias, presidente. Vamos a escuchar al alcalde
# de Magidas a continuación. Alcalde, acaba por ser el alcalde, antes terminaremos con los auditoriales. El alcalde, por f
# avor. Bien. En primer instante, para saludarle a la congresista Elisa Valle-Marina, señor vice ministro de agricultura,
# funcionarios que la acompañan, alcaldes de diferentes provincias, distritos, autoridades, hermanos pobladores, hermanos
# agricultores, recibo un cordial saludo de muy buenas tardes en nombre de la municipalidad distrital de Magidas. Primeram
# ente, congresista, para poder felicitarle por esta reunión para poder articular, para poder escuchar al pueblo que hoy s
# e ha programado esta vez en pública. Como también nosotros lo hacemos en los pueblos y con todo el pueblo que vivimos ha
# ciendo. De igual manera, señores ministros, nosotros como hijos de agricultores, como hijos del campo, estamos en la mis
# ma situación que los agricultores y los agricultores que nos han ayudado en este momento. Hoy en día no hemos avanzado l
# o que es debo certificado casi ninguna provincia, ningún distrito. Mi distrito de Magidas es un distrito amplio tiene ci
# erre y cerro. Entonces no tenemos ni un riego de libertad en el momento. Y hoy nosotros queremos hacer los experimentos.
#  Y también otra parte a veces ser ejecutado en el centro poblado de Catapulto, Tite, Ututo, que es más de la provincia d
# e Catapulto. Y también otra parte a veces ser ejecutado en el centro poblado de Catapulto, Tite,
